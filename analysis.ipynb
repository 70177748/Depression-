# %% [markdown]
# # Reddit Depression Dashboard — EDA Notebook
# This notebook supports the Streamlit dashboard with dataset loading, cleaning, and exploratory analysis.

# %%
from pathlib import Path
import pandas as pd

files = list(Path('../data').glob('*.csv')) + list(Path('../data').glob('*.xlsx'))
files[:3]

# %%
df = pd.read_csv(files[0]) if files[0].suffix == '.csv' else pd.read_excel(files[0])
df.head()

# %%
df.info()
df.describe(include='all').T.head(20)
